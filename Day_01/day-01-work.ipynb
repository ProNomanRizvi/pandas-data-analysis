# %%
import pandas as pd

# %% [markdown]
# ### Read **CSV** File

# %%
df = pd.read_csv("/content/drive/MyDrive/Pandas for Data Analysis/Pandas/sample_data.csv")
print("Data is")
print(df)
# Out:
# Data is
#    StudentID           Name  Subject  Midterm  Final Grade
# 0       1001    Alice Green     Math       85     90     A
# 1       1002      Bob White     Math       70     75     B
# 2       1003  Charlie Black     Math       60     65     C
# 3       1001    Alice Green  Science       88     92     A
# 4       1002      Bob White  Science       80     85     B
# 5       1003  Charlie Black  Science       55     60     D

# %% [markdown]
# ### Read **Excel** File

# %%
df = pd.read_excel("/content/drive/MyDrive/Pandas for Data Analysis/Data/SampleSuperstore.xlsx")
print("Data is")
print(df)
# Out:
# Data is
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# ### Read **JSON** File

# %%
df = pd.read_json("/content/drive/MyDrive/Pandas for Data Analysis/Data/sample_Data.json")
print("Data is")
print(df)
# Out:
# Data is
#     id                                               name  \
# 0    1                                    Apple iPhone 12
# 1    2                                 Samsung Galaxy S21
# 2    3                                 Sony PlayStation 5
# 3    4                  LG OLED55CXPUA 55-inch 4K OLED TV
# 4    5        Bose QuietComfort 35 II Wireless Headphones
# 5    6                          Fitbit Versa 3 Smartwatch
# 6    7                             KitchenAid Stand Mixer
# 7    8                 Dyson V11 Absolute Cordless Vacuum
# 8    9                         Ninja Foodi Smart XL Grill
# 9   10                    Canon EOS Rebel T8i DSLR Camera
# 10  11                                  Apple AirPods Pro
# 11  12        Bose QuietComfort 35 II Wireless Headphones
# 12  13                    Fitbit Charge 4 Fitness Tracker
# 13  14                              Samsung Galaxy Watch3
# 14  15  Sony WH-1000XM4 Wireless Noise-Cancelling Head...
# ...

# %% [markdown]
# ### **Save Data**

# %%
data = {
    "Name": ["Noman", "Shah Nawaz", "Riaz Hussain", "Huzaifa Iqbal", "Haseeb Hassan" , "Tayyab", "Samiullah", "Talha Fahad", "Saad"],
    "Age": [20, 21, 20, 22, 19, 20, 19, 20, 21]
}

df = pd.DataFrame(data)
print(df)

# df.to_csv("/content/drive/MyDrive/Pandas for Data Analysis/Day_01/sample_data.csv", index=False)
df.to_excel("/content/drive/MyDrive/Pandas for Data Analysis/Day_01/sample_data.xlsx", index=False)
df.to_json("/content/drive/MyDrive/Pandas for Data Analysis/Day_01/sample_data.json", index=False)
# Out:
#             Name  Age
# 0          Noman   20
# 1     Shah Nawaz   21
# 2   Riaz Hussain   20
# 3  Huzaifa Iqbal   22
# 4  Haseeb Hassan   19
# 5         Tayyab   20
# 6      Samiullah   19
# 7    Talha Fahad   20
# 8           Saad   21
