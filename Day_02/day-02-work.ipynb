# %% [markdown]
# # **Previewing the Data**

# %%
import pandas as pd
data_path = "/content/drive/MyDrive/Pandas for Data Analysis/Data/sales_data_sample.csv"

# %% [markdown]
# ### View First **10** Rows
# using ***`head()`***

# %%
df = pd.read_csv(data_path, encoding="latin1")
df.head(10)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# ...

# %% [markdown]
# ### View Last **10** Rows
# using ***`tail()`***

# %%
df = pd.read_csv(data_path, encoding="latin1")
df.tail(10)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2813        10293               32      60.06                1  1921.92
# 2814        10306               35      59.51                6  2082.85
# 2815        10315               40      55.69                5  2227.60
# 2816        10327               37      86.74                4  3209.38
# 2817        10337               42      97.16                5  4080.72
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2813    9/9/2004 0:00   Shipped       3         9     2004  ...
# ...

# %% [markdown]
# # **Summry of Data**
# using **`info()`** method

# %%
df = pd.read_csv(data_path, encoding="latin1")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %% [markdown]
# # **Descriptive Statistics of DataFrame**

# %%
data_01 = {
    "Name": ["John", "Jane", "Bob", "Alice"],
    "Age": [25, 30, 35, 40],
    "Salary": [50000, 60000, 70000, 80000],
    "Department": ["IT", "HR", "IT", "Finance"]
}

df = pd.DataFrame(data_01)
print(df)
print("-------------------")
print("Descriptive Statistics")
print(df.describe())
# Out:
#     Name  Age  Salary Department
# 0   John   25   50000         IT
# 1   Jane   30   60000         HR
# 2    Bob   35   70000         IT
# 3  Alice   40   80000    Finance
# -------------------
# Descriptive Statistics
#              Age        Salary
# count   4.000000      4.000000
# mean   32.500000  65000.000000
# std     6.454972  12909.944487
# min    25.000000  50000.000000
# 25%    28.750000  57500.000000
# 50%    32.500000  65000.000000
# 75%    36.250000  72500.000000
# max    40.000000  80000.000000

# %% [markdown]
# ### Load Data
# Reading data from file into DataFrame

# %%
data = "/content/drive/MyDrive/Pandas for Data Analysis/Data/sample_data.csv"
df = pd.read_csv(data)
print(df.head())
print("-------------------")
print(df.describe())
# Out:
#    StudentID           Name  Subject  Midterm  Final Grade
# 0       1001    Alice Green     Math       85     90     A
# 1       1002      Bob White     Math       70     75     B
# 2       1003  Charlie Black     Math       60     65     C
# 3       1001    Alice Green  Science       88     92     A
# 4       1002      Bob White  Science       80     85     B
# -------------------
#          StudentID   Midterm      Final
# count     6.000000   6.00000   6.000000
# mean   1002.000000  73.00000  77.833333
# std       0.894427  13.56466  13.347909
# min    1001.000000  55.00000  60.000000
# 25%    1001.250000  62.50000  67.500000
# 50%    1002.000000  75.00000  80.000000
# 75%    1002.750000  83.75000  88.750000
# max    1003.000000  88.00000  92.000000
